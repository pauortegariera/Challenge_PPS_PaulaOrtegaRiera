# %%
import pandas as pd

df= pd.read_csv('0000002_00005_d_0000014.txt', index_col=0) # Se realiza la carga del data frame.
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df= pd.read_csv('0000002_00005_d_0000014.txt', index_col=0, header=None) # Se realiza la carga del data frame.
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df= pd.read_csv('0000002_00005_d_0000014.txt', index_col=0, header=header) # Se realiza la carga del data frame.
header= ['Clase','X posición','Y posición','Ancho','Alto']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a339c5345ca5> in <module>
# ----> 1 df= pd.read_csv('0000002_00005_d_0000014.txt', index_col=0, header=header) # Se realiza la carga del data frame.
#       2 header= ['Clase','X posición','Y posición','Ancho','Alto']
#
# NameError: name 'header' is not defined

# %%
header= ['Clase','X posición','Y posición','Ancho','Alto']
df= pd.read_csv('0000002_00005_d_0000014.txt', index_col=0, header=header) # Se realiza la carga del data frame.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-2c8f9a1114f0> in <module>
#       1 header= ['Clase','X posición','Y posición','Ancho','Alto']
# ----> 2 df= pd.read_csv('0000002_00005_d_0000014.txt', index_col=0, header=header) # Se realiza la carga del data frame.
#
# ...

# %%
clear all

df= pd.read_csv('0000002_00005_d_0000014.txt', index_col=0, header=None) # Se realiza la carga del data frame.
# Out:
#   File "<ipython-input-21-c09f2d0a2647>", line 1
#     clear all
#           ^
# SyntaxError: invalid syntax

# %%
df= pd.read_csv('0000002_00005_d_0000014.txt', delimiter=' ',index_col=None, header=None ) # Se realiza la carga del data frame.
df
# Out:
#      0         1         2         3         4
# 0    0  0.854688  0.122222  0.284375  0.214815
# 1    0  0.560938  0.285185  0.276042  0.129630
# 2    0  0.327604  0.159259  0.123958  0.237037
# 3    0  0.109896  0.077778  0.217708  0.144444
# 4    4  0.776042  0.902778  0.077083  0.061111
# ..  ..       ...       ...       ...       ...
# 83  10  0.144792  0.227778  0.006250  0.014815
# 84  10  0.886979  0.925926  0.021875  0.048148
# 85   0  0.967708  0.325000  0.035417  0.135185
# 86   2  0.236458  0.649074  0.008333  0.020370
# 87   2  0.346354  0.308333  0.007292  0.020370
#
# [88 rows x 5 columns]

# %%
# Out:
#                   0         1         2         3         4
# 0   ignored regions  0.854688  0.122222  0.284375  0.214815
# 1   ignored regions  0.560938  0.285185  0.276042  0.129630
# 2   ignored regions  0.327604  0.159259  0.123958  0.237037
# 3   ignored regions  0.109896  0.077778  0.217708  0.144444
# 4               car  0.776042  0.902778  0.077083  0.061111
# ..              ...       ...       ...       ...       ...
# 83            motor  0.144792  0.227778  0.006250  0.014815
# 84            motor  0.886979  0.925926  0.021875  0.048148
# 85  ignored regions  0.967708  0.325000  0.035417  0.135185
# 86           people  0.236458  0.649074  0.008333  0.020370
# 87           people  0.346354  0.308333  0.007292  0.020370
#
# [88 rows x 5 columns]

# %%
df.iloc[:,0:1] # se selecciona la columna de interés
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    4
# ..  ..
# 83  10
# 84  10
# 85   0
# 86   2
# 87   2
#
# [88 rows x 1 columns]

# %%
lista_clases=df[0].tolist() # se convierte la columna en una lista
len(lista_clases)# verifico la cantidad de elementos de la lista
# Out:
# 88

# %%
df.lista_clases.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-6dccb56fd93c> in <module>
# ----> 1 df.lista_clases.unique()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'lista_clases'
